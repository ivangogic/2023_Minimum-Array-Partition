# %%
from minarrpar.common.instance import Instance
from minarrpar.common.solution import Solution

# %%
from minarrpar.methods.genetic_algorithm import ga
from minarrpar.methods.brute_force import bf
from minarrpar.methods.s_metaheuristics import sa, vns

# %%
instance = Instance('tests/squared_n50_p3.in')

# %%
import numpy as np
print('E =', np.sum(instance.matrix) / (instance.p ** 2))
# Out:
# E = 449444.44444444444

# %%
ga(instance=instance,
   pop_size=100,
   num_iters=500,
   tournament_size=5,
   mutation_prob=0.35,
   elitism_size=20,
   disabled_pbar=False)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Solution(
#   h = [ 0 24 40 50]
#   v = [ 0 24 40 50]
#   result = 520720
# )

# %%
bf(instance=instance, disabled_pbar=False)
# Out:
#   0%|          | 0/1382976 [00:00<?, ?it/s]
# Solution(
#   h = [ 0 24 40 50]
#   v = [ 0 24 40 50]
#   result = 520720
# )

# %%
sa(instance=instance,
   num_iters=1000,
   disabled_pbar=False)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Solution(
#   h = [ 0 24 40 50]
#   v = [ 0 24 40 50]
#   result = 520720
# )

# %%
vns(instance=instance,
    num_iters=10000,
    k_max=15,
    move_prob=0.5,
    disabled_pbar=False)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# Solution(
#   h = [ 0 24 40 50]
#   v = [ 0 24 40 50]
#   result = 520720
# )
