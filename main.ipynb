# %%
from minarrpar.common.instance import Instance

# %%
from minarrpar.methods.ga import ga
from minarrpar.methods.bf import bf

# %%
instance = Instance('tests/generated_n40_p3.in')

# %%
import numpy as np
print('E =', np.sum(instance.matrix) / (instance.p ** 2))
# Out:
# E = 961.4444444444445

# %%
VERBOSE = False

# %%
ga(instance=instance, 
   pop_size=100, 
   num_iters=500, 
   tournament_size=5, 
   mutation_prob=0.35, 
   elitism_size=20, 
   verbose=VERBOSE)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# ----------
# h = array([ 0, 14, 27, 40])
# v = array([ 0, 13, 26, 40])
# fitness = 0.0009633911368015414
# value = 1038.0

# %%
bf(instance=instance, verbose=VERBOSE)
# Out:
#   0%|          | 0/549081 [00:00<?, ?it/s]
# ----------
# result_h = [0, 14, 27, 40]
# result_v = [0, 13, 26, 40]
# result = 1038.0
